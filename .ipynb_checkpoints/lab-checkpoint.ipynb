# %% [markdown]
# # Map
#
# # Italy = 1
#
# # Germany = 2
#
# # Japneas = 3

# %%
26 of july scusa

# %%
30 of july scusa

# %%
 2 4 8 16 32 64 128 256 365

# %%
Reapeations_number = [ 2 , 4 , 8 , 16 , 32 , 64 , 128 , 256 ]
